# %% [markdown]
# #Data Ready & Basic Analysis:

# %%
# Import the numpy and pandas package
import numpy as np
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#To load dataset in google colab from github
url = 'https://raw.githubusercontent.com/Mondol007/Datasets/main/Mercury_Predictions_First.csv'
df1 = pd.read_csv(url)

# %%
df1.head(5)
# Out:
#        Reservoir  Fish  Mercury  Elevation  Drainage Area  Surface Area  \
# 0        Abilene     3    0.053        196            6.0            74
# 1   Abraham Lake     4    0.350        345           15.0           360
# 2        Academy     5    0.540        487            1.0           175
# 3         Acadia     5    0.290        165          131.0          5543
# 4  Acadia Valley     5    0.910       1273           65.0           700
#
#    Max Depth    RF   FR  Dam   RT   RS
# 0       36.0  0.44  1.1  1.0  2.0  0.0
# 1       80.0  0.51  1.7  0.0  3.0  1.0
# 2       10.0  0.57  1.5  0.0  3.0  0.0
# 3      100.0  0.51  1.1  0.0  2.0  1.0
# 4      106.0  0.62  4.3  0.0  1.0  1.0

# %%
url2 = 'https://raw.githubusercontent.com/Mondol007/Datasets/main/Mercury_Predictions.csv'
df2 = pd.read_csv(url2)

# %%
df2.head(5)
# Out:
#        Reservoir  LATITUDE_DEGREES  LATITUDE_MINUTES  LATITUDE_SECONDS  \
# 0        Abilene                44                57                44
# 1   Abraham Lake                45                37                50
# 2        Academy                44                25                13
# 3         Acadia                43                37                 0
# 4  Acadia Valley                45                30                32
#
#    LONGITUDE_DEGREES  LONGITUDE_MINUTES  LONGITUDE_SECONDS
# 0                 68                  5                  7
# 1                 69                 12                 30
# 2                 70                 19                 22
# 3                 70                 59                  4
# 4                 67                 50                  2

# %%
df1.dtypes
# Out:
# Reservoir         object
# Fish               int64
# Mercury          float64
# Elevation          int64
# Drainage Area    float64
# Surface Area       int64
# Max Depth        float64
# RF               float64
# FR               float64
# Dam              float64
# RT               float64
# RS               float64
# dtype: object

# %%
df2.dtypes
# Out:
# Reservoir            object
# LATITUDE_DEGREES      int64
# LATITUDE_MINUTES      int64
# LATITUDE_SECONDS      int64
# LONGITUDE_DEGREES     int64
# LONGITUDE_MINUTES     int64
# LONGITUDE_SECONDS     int64
# dtype: object

# %%
#For joining two datasets
df3 = pd.merge(df1, df2)
df3.head(5)
# Out:
#        Reservoir  Fish  Mercury  Elevation  Drainage Area  Surface Area  \
# 0        Abilene     3    0.053        196            6.0            74
# 1   Abraham Lake     4    0.350        345           15.0           360
# 2        Academy     5    0.540        487            1.0           175
# 3         Acadia     5    0.290        165          131.0          5543
# 4  Acadia Valley     5    0.910       1273           65.0           700
#
#    Max Depth    RF   FR  Dam   RT   RS  LATITUDE_DEGREES  LATITUDE_MINUTES  \
# 0       36.0  0.44  1.1  1.0  2.0  0.0                44                57
# 1       80.0  0.51  1.7  0.0  3.0  1.0                45                37
# 2       10.0  0.57  1.5  0.0  3.0  0.0                44                25
# 3      100.0  0.51  1.1  0.0  2.0  1.0                43                37
# 4      106.0  0.62  4.3  0.0  1.0  1.0                45                30
#
#    LATITUDE_SECONDS  LONGITUDE_DEGREES  LONGITUDE_MINUTES  LONGITUDE_SECONDS
# 0                44                 68                  5                  7
# 1                50                 69                 12                 30
# 2                13                 70                 19                 22
# 3                 0                 70                 59                  4
# 4                32                 67                 50                  2

# %%
df3.shape
# Out:
# (121, 18)

# %%
#Attribute length
len(set(df3))
# Out:
# 18

# %%
df3.describe()
# Out:
#              Fish     Mercury    Elevation  Drainage Area  Surface Area  \
# count  121.000000  121.000000   121.000000     118.000000    121.000000
# mean     4.280992    0.489661   570.041322      41.957627    895.809917
# std      1.081844    0.353842   433.400823     116.554554   1978.127664
# min      1.000000    0.025000    15.000000       0.000000     12.000000
# 25%      4.000000    0.250000   247.000000       2.000000     83.000000
# 50%      5.000000    0.410000   416.000000       6.000000    234.000000
# 75%      5.000000    0.660000   846.000000      20.500000    630.000000
# max      6.000000    2.500000  1700.000000     762.000000  14340.000000
#
#         Max Depth          RF          FR         Dam          RT          RS  \
# count  120.000000  114.000000  114.000000  118.000000  120.000000  119.000000
# mean    41.133333    0.550702    6.207018    0.601695    2.200000    0.554622
# std     29.856219    0.100157   11.455947    0.491637    0.717137    0.499109
# min      5.000000    0.060000    0.100000    0.000000    1.000000    0.000000
# 25%     21.000000    0.510000    0.900000    0.000000    2.000000    0.000000
# 50%     35.000000    0.560000    2.050000    1.000000    2.000000    1.000000
# 75%     50.000000    0.610000    5.700000    1.000000    3.000000    1.000000
# max    158.000000    0.760000   64.100000    1.000000    3.000000    1.000000
#
#        LATITUDE_DEGREES  LATITUDE_MINUTES  LATITUDE_SECONDS  \
# count        121.000000        121.000000        121.000000
# mean          44.528926         28.553719         29.454545
# std            0.913550         16.626260         17.516183
# min           43.000000          0.000000          0.000000
# 25%           44.000000         15.000000         14.000000
# 50%           44.000000         27.000000         28.000000
# 75%           45.000000         44.000000         45.000000
# max           47.000000         59.000000         59.000000
#
#        LONGITUDE_DEGREES  LONGITUDE_MINUTES  LONGITUDE_SECONDS
# count         121.000000         121.000000         121.000000
# mean           68.859504          30.305785          30.743802
# std             0.977290          17.921980          15.807977
# min            67.000000           0.000000           1.000000
# 25%            68.000000          15.000000          18.000000
# 50%            69.000000          31.000000          31.000000
# 75%            70.000000          46.000000          44.000000
# max            71.000000          59.000000          59.000000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Reservoir          121 non-null    object
#  1   Fish               121 non-null    int64
#  2   Mercury            121 non-null    float64
#  3   Elevation          121 non-null    int64
#  4   Drainage Area      118 non-null    float64
#  5   Surface Area       121 non-null    int64
#  6   Max Depth          120 non-null    float64
#  7   RF                 114 non-null    float64
#  8   FR                 114 non-null    float64
#  9   Dam                118 non-null    float64
#  10  RT                 120 non-null    float64
#  11  RS                 119 non-null    float64
#  12  LATITUDE_DEGREES   121 non-null    int64
#  13  LATITUDE_MINUTES   121 non-null    int64
#  14  LATITUDE_SECONDS   121 non-null    int64
#  15  LONGITUDE_DEGREES  121 non-null    int64
#  16  LONGITUDE_MINUTES  121 non-null    int64
#  17  LONGITUDE_SECONDS  121 non-null    int64
# dtypes: float64(8), int64(9), object(1)
# memory usage: 17.1+ KB

# %%
data = df3[['Reservoir', 'Mercury']]

# %%
plt.figure(figsize = (10, 6))
plt.plot(data['Mercury'])
plt.title('Mercury level among Fish')
plt.ylabel('Mercury')
plt.xlabel('Reservoir')
plt.show()

# %% [markdown]
# # Data Cleaning & Train Test Split:

# %%
df3.isnull().sum()
# Out:
# Reservoir            0
# Fish                 0
# Mercury              0
# Elevation            0
# Drainage Area        3
# Surface Area         0
# Max Depth            1
# RF                   7
# FR                   7
# Dam                  3
# RT                   1
# RS                   2
# LATITUDE_DEGREES     0
# LATITUDE_MINUTES     0
# LATITUDE_SECONDS     0
# LONGITUDE_DEGREES    0
# LONGITUDE_MINUTES    0
# LONGITUDE_SECONDS    0
# dtype: int64

# %%
#Filling null values with median
df3[['Drainage Area', 'RF', 'FR']] = df3[['Drainage Area', 'RF', 'FR']].fillna(df3[['Drainage Area', 'RF', 'FR']].median())

# %%
df3.isnull().sum()
# Out:
# Reservoir            0
# Fish                 0
# Mercury              0
# Elevation            0
# Drainage Area        0
# Surface Area         0
# Max Depth            1
# RF                   0
# FR                   0
# Dam                  3
# RT                   1
# RS                   2
# LATITUDE_DEGREES     0
# LATITUDE_MINUTES     0
# LATITUDE_SECONDS     0
# LONGITUDE_DEGREES    0
# LONGITUDE_MINUTES    0
# LONGITUDE_SECONDS    0
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3.isnull().sum()
# Out:
# Reservoir            0
# Fish                 0
# Mercury              0
# Elevation            0
# Drainage Area        0
# Surface Area         0
# Max Depth            0
# RF                   0
# FR                   0
# Dam                  0
# RT                   0
# RS                   0
# LATITUDE_DEGREES     0
# LATITUDE_MINUTES     0
# LATITUDE_SECONDS     0
# LONGITUDE_DEGREES    0
# LONGITUDE_MINUTES    0
# LONGITUDE_SECONDS    0
# dtype: int64

# %%
df3.shape
# Out:
# (117, 18)

# %%
#features
feature = df3
feature = feature.drop('Reservoir', axis=1)
feature = feature.drop('Mercury', axis=1)

# %%
feature.shape
# Out:
# (117, 16)

# %%
#label
label = df3['Mercury']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(feature, label,test_size=.2,random_state=42)

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape
# Out:
# ((93, 16), (93,), (24, 16), (24,))

# %% [markdown]
# # Feature Engineering:

# %%
import statsmodels.api as sm
train_x_sm = sm.add_constant(train_x)
train_x_sm.head(5)
# Out:
#     const  Fish  Elevation  Drainage Area  Surface Area  Max Depth    RF  \
# 15    1.0     5        296            1.0            87       15.0  0.47
# 73    1.0     4        269            3.0           134       30.0  0.47
# 33    1.0     5        101            0.0            49       18.0  0.51
# 25    1.0     5        519            6.0          1222       88.0  0.56
# 59    1.0     5        446            7.0           576       25.0  0.56
#
#       FR  Dam   RT   RS  LATITUDE_DEGREES  LATITUDE_MINUTES  LATITUDE_SECONDS  \
# 15  2.00  1.0  2.0  0.0                44                54                 0
# 73  2.10  1.0  2.0  1.0                44                19                43
# 33  0.90  1.0  3.0  0.0                45                45                 4
# 25  2.05  1.0  1.0  1.0                46                24                26
# 59  1.10  1.0  2.0  0.0                44                15                54
#
#     LONGITUDE_DEGREES  LONGITUDE_MINUTES  LONGITUDE_SECONDS
# 15                 68                 14                 45
# 73                 70                 24                  1
# 33                 69                  4                 43
# 25                 69                  2                 18
# 59                 70                 50                 13

# %%
lr = sm.OLS(train_y, train_x).fit()
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                Mercury   R-squared (uncentered):                   0.731
# Model:                            OLS   Adj. R-squared (uncentered):              0.675
# Method:                 Least Squares   F-statistic:                              13.05
# Date:                Tue, 29 Oct 2024   Prob (F-statistic):                    6.87e-16
# Time:                        12:34:12   Log-Likelihood:                         -24.837
# No. Observations:                  93   AIC:                                      81.67
# Df Residuals:                      77   BIC:                                      122.2
# Df Model:                          16
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Fish                 -0.0191      0.036     -0.530      0.597      -0.091       0.053
# Elevation            -0.0003     0.0001     -3.181      0.002      -0.001      -0.000
# Drainage Area         0.0002      0.001      0.410      0.683      -0.001       0.001
# Surface Area      -6.277e-06   2.79e-05     -0.225      0.823   -6.19e-05    4.93e-05
# Max Depth            -0.0029      0.002     -1.544      0.127      -0.007       0.001
# RF                    0.0667      0.361      0.185      0.854      -0.652       0.786
# FR                   -0.0042      0.003     -1.230      0.222      -0.011       0.003
# Dam                   0.0126      0.084      0.150      0.881      -0.155       0.180
# RT                   -0.0268      0.062     -0.431      0.668      -0.151       0.097
# RS                    0.1372      0.094      1.453      0.150      -0.051       0.325
# LATITUDE_DEGREES      0.0015      0.030      0.048      0.962      -0.059       0.062
# LATITUDE_MINUTES  -1.305e-05      0.003     -0.005      0.996      -0.005       0.005
# LATITUDE_SECONDS      0.0010      0.002      0.436      0.664      -0.003       0.005
# LONGITUDE_DEGREES     0.0097      0.020      0.475      0.636      -0.031       0.051
# LONGITUDE_MINUTES    -0.0006      0.002     -0.280      0.780      -0.005       0.004
# LONGITUDE_SECONDS     0.0029      0.003      1.169      0.246      -0.002       0.008
# ==============================================================================
# Omnibus:                       52.814   Durbin-Watson:                   2.286
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              231.673
# Skew:                           1.797   Prob(JB):                     4.93e-51
# Kurtosis:                       9.846   Cond. No.                     2.29e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Those columns are taken where p_value<0.5

# %%
train_x.head(5)
# Out:
#     Fish  Elevation  Drainage Area  Surface Area  Max Depth    RF    FR  Dam  \
# 15     5        296            1.0            87       15.0  0.47  2.00  1.0
# 73     4        269            3.0           134       30.0  0.47  2.10  1.0
# 33     5        101            0.0            49       18.0  0.51  0.90  1.0
# 25     5        519            6.0          1222       88.0  0.56  2.05  1.0
# 59     5        446            7.0           576       25.0  0.56  1.10  1.0
#
#      RT   RS  LATITUDE_DEGREES  LATITUDE_MINUTES  LATITUDE_SECONDS  \
# 15  2.0  0.0                44                54                 0
# 73  2.0  1.0                44                19                43
# 33  3.0  0.0                45                45                 4
# 25  1.0  1.0                46                24                26
# 59  2.0  0.0                44                15                54
#
#     LONGITUDE_DEGREES  LONGITUDE_MINUTES  LONGITUDE_SECONDS
# 15                 68                 14                 45
# 73                 70                 24                  1
# 33                 69                  4                 43
# 25                 69                  2                 18
# 59                 70                 50                 13

# %%
train_y.head()
# Out:
# 15    0.19
# 73    0.51
# 33    0.28
# 25    0.22
# 59    0.31
# Name: Mercury, dtype: float64

# %% [markdown]
# So, now a new dataset to be extracted from previous dataset with attributes having p value <0.5

# %%
df_main = df3[['Mercury', 'Elevation', 'Max Depth', 'FR', 'RS', 'LONGITUDE_SECONDS']]

# %%
df_main.head(5)
# Out:
#    Mercury  Elevation  Max Depth   FR   RS  LONGITUDE_SECONDS
# 0    0.053        196       36.0  1.1  0.0                  7
# 1    0.350        345       80.0  1.7  1.0                 30
# 2    0.540        487       10.0  1.5  0.0                 22
# 3    0.290        165      100.0  1.1  1.0                  4
# 4    0.910       1273      106.0  4.3  1.0                  2

# %% [markdown]
# Again Train Test Split for extracted dataset: df_main

# %%
#features
feature = df_main
feature = feature.drop('Mercury', axis=1)

# %%
feature.shape
# Out:
# (117, 5)

# %%
#labels
label = df3['Mercury']

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(feature, label,test_size=.2,random_state=42)

# %%
train_x.shape, train_y.shape, test_x.shape, test_y.shape
# Out:
# ((93, 5), (93,), (24, 5), (24,))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
lr.score(test_x, test_y)
# Out:
# -0.42791436190740395

# %%
pred_y = lr.predict(test_x)
pred_y
# Out:
# array([0.62545308, 0.12393221, 0.54547409, 0.39401351, 0.46799789,
#        0.56104297, 0.62931002, 0.59429127, 0.50165417, 0.33032442,
#        0.34012498, 0.38762539, 0.39531458, 0.661405  , 0.52352859,
#        0.49260571, 0.61778212, 0.60903683, 0.44105228, 0.17295054,
#        0.66501167, 0.64187068, 0.25844907, 0.28620038])

# %%
import math
import sklearn.metrics
mse = sklearn.metrics.mean_squared_error(test_y, pred_y)
rmse = math.sqrt(mse)
rmse
# Out:
# 0.2927825573865299

# %% [markdown]
# #Visualizaion, Cross Validation & Model Building:

# %% [markdown]
# Most important columns are taken for ploting

# %%
df_main.columns
# Out:
# Index(['Mercury', 'Elevation', 'Max Depth', 'FR', 'RS', 'LONGITUDE_SECONDS'], dtype='object')

# %%
sns.pairplot(df_main)

# %%
plt.scatter(df_main['Mercury'], df_main['Elevation'])
plt.plot(df_main['Mercury'], 10 + 1050*df_main['Mercury'], 'r')
plt.title('Mercury level vs Elevation')
plt.ylabel('Mercury')
plt.xlabel('Elevation')
plt.show()

# %%
plt.scatter(df_main['Mercury'], df_main['Max Depth'])
plt.plot(df_main['Mercury'], 10 + 50*df_main['Mercury'], 'r')
plt.title('Mercury level vs Max Depth')
plt.ylabel('Mercury')
plt.xlabel('Max Depth')
plt.show()

# %%
plt.scatter(df_main['Mercury'], df_main['FR'])
plt.plot(df_main['Mercury'], 1.8 + 1*df_main['Mercury'], 'r')
plt.title('Mercury level vs FR')
plt.ylabel('Mercury')
plt.xlabel('FR')
plt.show()

# %%
plt.scatter(df_main['Mercury'], df_main['RS'])
plt.plot(df_main['Mercury'], .5 + .001*df_main['Mercury'], 'r')
plt.title('Mercury level vs RS')
plt.ylabel('Mercury')
plt.xlabel('RS')
plt.show()

# %%
plt.scatter(df_main['Mercury'], df_main['LONGITUDE_SECONDS'])
plt.plot(df_main['Mercury'], 8 + 45*df_main['Mercury'], 'r')
plt.title('Mercury level vs LONGITUDE_SECONDS')
plt.ylabel('Mercury')
plt.xlabel('LONGITUDE_SECONDS')
plt.show()

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from numpy import mean, sqrt, absolute
import math
import sklearn.metrics

lm = LinearRegression()
scores = cross_val_score(lm, train_x, train_y, scoring='r2', cv=10)
absolute(scores)
# Out:
# array([0.38665053, 0.13270732, 0.1976661 , 0.08790449, 1.31084336,
#        0.78091206, 0.32264109, 0.17419759, 0.20711038, 0.44517027])

# %%
mean(absolute(scores))
# Out:
# 0.40458031953502516

# %%
from sklearn.metrics import r2_score
r2_score(test_y, pred_y)
# Out:
# -0.42791436190740395

# %%
lm = LinearRegression()
score_1 = cross_val_score(lm, train_x, train_y, scoring='r2', cv=10)
score_2 = cross_val_score(lm, train_x, train_y, scoring='neg_root_mean_squared_error', cv=10)

# %%
score_1
# Out:
# array([-0.38665053,  0.13270732, -0.1976661 ,  0.08790449, -1.31084336,
#        -0.78091206,  0.32264109,  0.17419759,  0.20711038, -0.44517027])

# %%
score_1.mean()
# Out:
# -0.21966814485699104

# %% [markdown]
# R2 score can be negative because of small dataset and noise in the dataset

# %%
np.absolute(score_2)
# Out:
# array([0.28687336, 0.26964857, 0.27278159, 0.29204634, 0.26788369,
#        0.32893814, 0.28523382, 0.64455963, 0.27342399, 0.31836238])

# %%
np.absolute(score_2.mean())
# Out:
# 0.32397515137713145
